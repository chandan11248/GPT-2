# %%
with open("doc.txt", "r", encoding="utf-8") as f:
    raw_txt = f.read()

print("total length",len(raw_txt))
raw_txt[:50]
# Out:
# total length 5801
# '🌙 The Moon-Sealed Quest — A Story of Arcana, Frien'

# %%
import re

txt = "my name is chandan shah.what is your name?"
result = re.split(r'([,.:;?_!"()\']|--|\s)', txt)
# Strip each item and filter out empty strings
result = [item for item in result if item.strip()]
print(result)
# Out:
# ['my', 'name', 'is', 'chandan', 'shah', '.', 'what', 'is', 'your', 'name', '?']

# %%
preprocessed=re.split(r'([,.:;?_!"-()\']|--|\s)',raw_txt)
preprocessed=[item for item in preprocessed if item.strip()]
print(preprocessed)
print(len(preprocessed))
# Out:
# ['🌙', 'The', 'Moon-Sealed', 'Quest', '—', 'A', 'Story', 'of', 'Arcana', ',', 'Friendship', ',', 'and', 'Destiny', 'In', 'a', 'land', 'where', 'forests', 'breathed', 'secrets', 'and', 'rivers', 'carried', 'echoes', 'of', 'forgotten', 'gods', ',', 'there', 'lay', 'a', 'kingdom', 'called', 'Atherwyn', '.', 'It', 'shimmered', 'beneath', 'two', 'moons—one', 'silver', ',', 'one', 'violet—whose', 'lights', 'intertwined', 'to', 'weave', 'the', 'magic', 'that', 'flowed', 'through', 'every', 'tree', ',', 'stone', ',', 'and', 'living', 'soul', '.', 'But', 'one', 'night', ',', 'the', 'violet', 'moon', 'flickered…', 'and', 'vanished', '.', 'A', 'chill', 'swept', 'through', 'Atherwyn', '.', 'Magic', 'dimmed', 'like', 'dying', 'embers', '.', 'Spells', 'faltered', '.', 'The', 'wind', 'whispered', 'a', 'name', 'it', 'had', 'not', 'spoken', 'in', 'a', 'thousand', 'years', ':', '“Eclipsara', '.', '”', 'Chapter', '1', '—', 'The', 'Girl', 'Who', 'Heard', 'the', 'Moon', 'Cry', 'Far', 'from', 'Atherwyn’s', 'marble', 'cities', ',', 'in', 'the', 'misty', 'village', 'of', 'Lyr’s', 'End', ',', 'lived', 'a', 'girl', 'named', 'Seren', 'Vale', '.', 'She', 'was', 'seventeen', ',', 'with', 'dusk-dark', 'hair', 'and', 'eyes', 'that', 'sometimes', 'shimmered', 'like', 'moonlight—especially', 'when', 'she', 'dreamed', '.', 'And', 'that', 'night', ',', 'she', 'dreamed', 'of', 'a', 'sky', 'bleeding', 'purple', '.', 'She', 'woke', 'to', 'a', 'strange', 'ache', 'in', 'her', 'chest', '.', 'Stepping', 'outside', ',', 'Seren', 'saw', 'the', 'silver', 'moon', 'alone', 'in', 'the', 'heavens', ',', 'trembling', 'as', 'if', 'afraid', '.', 'Then', 'she', 'heard', 'it—a', 'voice', 'soft', 'as', 'silk', 'but', 'heavy', 'with', 'despair', ':', '“The', 'violet', 'moon', 'is', 'chained', '.', 'The', 'world', 'is', 'unbalanced', '.', 'Seren', 'Vale…', 'you', 'must', 'free', 'me', '.', '”', 'Seren', 'fell', 'to', 'her', 'knees', '.', 'The', 'moon', 'had', 'spoken', 'her', 'name', '.', 'By', 'dawn', ',', 'she', 'knew', 'one', 'thing', ':', 'She', 'must', 'go', '.', 'Even', 'if', 'she', 'had', 'no', 'idea', 'where', '.', 'Chapter', '2', '—', 'Companions', 'of', 'Fate', 'As', 'she', 'left', 'her', 'village', ',', 'Seren', 'encountered', 'three', 'travelers', 'whose', 'destinies', 'were', 'tangled', 'with', 'hers', 'in', 'ways', 'none', 'of', 'them', 'yet', 'understood', '.', '1', '.', 'Cael', 'Thornheart', '—', 'The', 'Exiled', 'Knight', 'Once', 'a', 'captain', 'of', 'the', 'Moon', 'Guard', ',', 'now', 'a', 'man', 'shunned', 'for', 'a', 'crime', 'he', 'didn’t', 'commit', '.', 'He', 'carried', 'a', 'broken', 'blade', 'infused', 'with', 'dormant', 'lunar', 'magic', '.', '2', '.', 'Lyra', 'Windsong', '—', 'Sprite', 'of', 'the', 'Whisperwood', 'Barely', 'two', 'feet', 'tall', ',', 'mischievous', ',', 'winged', ',', 'and', 'glowing', 'faintly', 'blue', '.', 'She', 'could', 'hear', 'the', 'thoughts', 'of', 'trees', 'and', 'speak', 'the', 'language', 'of', 'rivers', '.', '3', '.', 'Thorn', '—', 'A', 'Stoneborn', 'Wanderer', 'A', 'hulking', 'being', 'carved', 'of', 'living', 'granite', ',', 'yet', 'gentle', 'and', 'thoughtful', '.', 'His', 'kind', 'were', 'said', 'to', 'have', 'been', 'sculpted', 'by', 'the', 'moons', 'themselves', '.', 'When', 'Seren', 'told', 'them', 'what', 'she', 'had', 'heard', ',', 'Cael’s', 'eyes', 'widened', '.', '“The', 'moon', 'only', 'speaks', 'to', 'its', 'chosen', ',', '”', 'he', 'said', 'softly', '.', '“Then', 'I', 'guess', 'I’m', 'chosen', '?', '”', 'Seren', 'whispered', '.', 'Lyra', 'fluttered', 'anxiously', '.', '“Or', 'cursed', '!', '”', 'Thorn', 'nodded', 'solemnly', '.', '“Chosen', 'or', 'cursed', ',', 'little', 'moon-child', ',', 'your', 'path', 'is', 'etched', '.', 'We', 'follow', '.', '”', 'And', 'so', 'the', 'four', 'of', 'them', 'set', 'out', 'toward', 'the', 'Heart', 'of', 'Aether', ',', 'where', 'all', 'magic', 'converged—and', 'where', 'the', 'answers', 'waited', '.', 'Chapter', '3', '—', 'Trials', 'of', 'the', 'Shattered', 'Realms', 'Their', 'jo ...
# 1156

# %%
all_words=sorted(set(preprocessed))
vocab_size=len(all_words)
print(vocab_size)
# Out:
# 549

# %%
vocab={token:integer for integer ,token in enumerate(all_words)  }

# %%
class simpleTokenizerv1:
    def __init__(self,vocab):
        self.str_to_int=vocab
        self.int_to_str={i:s for s,i in vocab.items()}

    def encode(self,text):
        preprocessed=re.split(r'([,.:;?_!"-()\']|--|\s)',text)
        preprocessed=[item for item in preprocessed if item.strip()]
        ids = [self.str_to_int[s] for s in preprocessed]  
        return ids
    def decode(self,ids):
        text=" ".join([self.int_to_str[i] for i  in ids])
        text=re.sub(r'\s+([,.:;?_!"-()\'])',r'\1',text)
        return text

# %%
tokenizer=simpleTokenizerv1(vocab)
txt = """She must go.
Even if she had no idea where.
Chapter 2 — Companions of Fate """
ids=tokenizer.encode(txt)
print(ids)
# Out:
# [84, 360, 269, 2, 40, 297, 411, 273, 364, 296, 509, 2, 27, 4, 525, 29, 369, 43]

# %%
tokenizer.decode(ids=ids)
# Out:
# 'She must go. Even if she had no idea where. Chapter 2 — Companions of Fate'

# %% [markdown]
# >Now using end of text and tokinizer token

# %%
all_words = sorted(set(preprocessed))
all_words.extend(["<|endoftext|>", "<|unk|>"])  # don't assign back
vocab = {token: integer for integer, token in enumerate(all_words)}
print(len(vocab))
# Out:
# 551

# %%
class simpleTokenizerv2:
    def __init__(self,vocab):
        self.str_to_int=vocab
        self.int_to_str={i:s for s,i in vocab.items()}

    def encode(self,text):
        preprocessed=re.split(r'([,.:;?_!"-()\']|--|\s)',text)
        preprocessed=[item for item in preprocessed if item.strip()]
        preprocessed=[
            item if item in self.str_to_int
            else "<|unk|>" for item in preprocessed
        ]
        ids = [self.str_to_int[s] for s in preprocessed]  
        return ids
    def decode(self,ids):
        text=" ".join([self.int_to_str[i] for i  in ids])
        text=re.sub(r'\s+([,.:;?_!"-()\'])',r'\1',text)
        return text

# %%
tokenizer=simpleTokenizerv2(vocab=vocab)
text1="hi my self chandan shah"
text3=" Even if she had no idea where"
text2="i am a student."
text="<|endoftext|>".join((text1,text3,text2))

# %%
text
# Out:
# 'hi my self chandan shah<|endoftext|> Even if she had no idea where<|endoftext|>i am a student.'

# %%
ids=tokenizer.encode(text)

# %%
ids
# Out:
# [550, 550, 550, 550, 550, 40, 297, 411, 273, 364, 296, 550, 550, 108, 550, 2]

# %%
tokenizer.decode(ids)
# Out:
# '<|unk|> <|unk|> <|unk|> <|unk|> <|unk|> Even if she had no idea <|unk|> <|unk|> a <|unk|>.'
